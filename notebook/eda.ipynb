# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
ts = pd.read_csv("data\Microsoft_Stock.csv")
ts.head()
# Out:
#                 Date   Open   High    Low  Close    Volume
# 0  4/1/2015 16:00:00  40.60  40.76  40.31  40.72  36865322
# 1  4/2/2015 16:00:00  40.66  40.74  40.12  40.29  37487476
# 2  4/6/2015 16:00:00  40.34  41.78  40.18  41.55  39223692
# 3  4/7/2015 16:00:00  41.61  41.91  41.31  41.53  28809375
# 4  4/8/2015 16:00:00  41.48  41.69  41.04  41.42  24753438

# %%
ts.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1511 entries, 0 to 1510
# Data columns (total 6 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Date    1511 non-null   object
#  1   Open    1511 non-null   float64
#  2   High    1511 non-null   float64
#  3   Low     1511 non-null   float64
#  4   Close   1511 non-null   float64
#  5   Volume  1511 non-null   int64
# dtypes: float64(4), int64(1), object(1)
# memory usage: 71.0+ KB

# %%
ts.describe()
# Out:
#               Open         High          Low        Close        Volume
# count  1511.000000  1511.000000  1511.000000  1511.000000  1.511000e+03
# mean    107.385976   108.437472   106.294533   107.422091  3.019863e+07
# std      56.691333    57.382276    55.977155    56.702299  1.425266e+07
# min      40.340000    40.740000    39.720000    40.290000  1.016120e+05
# 25%      57.860000    58.060000    57.420000    57.855000  2.136213e+07
# 50%      93.990000    95.100000    92.920000    93.860000  2.662962e+07
# 75%     139.440000   140.325000   137.825000   138.965000  3.431962e+07
# max     245.030000   246.130000   242.920000   244.990000  1.352271e+08

# %%
ts.shape
# Out:
# (1511, 6)

# %%
ts.isnull().sum()
# Out:
# Date      0
# Open      0
# High      0
# Low       0
# Close     0
# Volume    0
# dtype: int64

# %%
ts.duplicated().sum()
# Out:
# np.int64(0)

# %%
ts.index = pd.to_datetime(ts['Date'])
ts = ts.drop(['Date'], axis = 1)

# %%
ts1 = ts[23:233]
ts1['Open'].plot(figsize = (15, 6))
# Out:
# <Axes: xlabel='Date'>

# %% [markdown]
# ####  📈 Overall Trend
# -  The stock starts around 47–48 in May 2015.
# - It ends around 53 in March 2016.
# -  Overall, the stock shows an upward trend, meaning Microsoft's value increased during this period.
# ####  📉 Downward Phase (May–September 2015)
# - Prices gradually decline from about 48 to 41.
# - The sharp drop around late August/early September indicates a significant market correction or company-related event.
# #### 📈 Recovery Phase (September–November 2015)
# - After reaching its lowest point (~40.5), the stock recovers steadily.
# - A noticeable jump occurs around late October/early November, suggesting positive news, earnings, or market sentiment.
# #### 📊 Strong Growth Period (November 2015–January 2016)
# - The stock remains mostly between 53–56.
# - It reaches its highest value around 56.5 in January 2016.
# #### 📉 Short-Term Volatility (January–March 2016)
# - Prices fluctuate between 49–55.
# - Despite these fluctuations, the stock stays well above its September lows.
# - Key Insights for Your Project
# ##### Trend: Upward (good for forecasting).
# ##### Seasonality: Not obvious from this single plot.
# ##### Volatility: Moderate, especially around Aug–Sep 2015 and Jan–Feb 2016.
# ##### Potential Outliers: Sharp drop in September and sharp rise in November.

# %% [markdown]
# Microsoft stock prices exhibited an overall upward trend during the observed period. The stock experienced a significant decline in September 2015, followed by a strong recovery and sustained growth until January 2016. Although short-term fluctuations were present, the long-term trend remained positive, indicating increasing investor confidence in the company

# %%
ts1 = ts[23:233]
ts1['Close'].plot(figsize = (15, 6))
# Out:
# <Axes: xlabel='Date'>

# %% [markdown]
# What this graph shows
# X-axis: Date (May 2015 – March 2016)
# Y-axis: Microsoft stock closing price
# Line: Daily closing price movement
# Key observations
# 1. Initial Decline (May–July 2015)
# Price falls from about 48.5 to 44.
# Indicates a bearish phase or profit booking.
# 2. Recovery (July–August 2015)
# Price recovers to around 47–48.
# Buyers start entering the market.
# 3. Sharp Drop (Late August 2015)
# Stock suddenly drops to around 40.5.
# This is the largest decline in the graph.
# Could be an external market event affecting technology stocks.
# 4. Strong Uptrend (September–January)
# Price rises steadily from 43 to 56.5.
# This is the strongest bullish trend in the dataset.
# The stock gains more than 30% from its low.
# 5. Correction (January–February)
# Price falls from 56.5 to around 49.
# Normal correction after a strong rally.
# 6. Stabilization (February–March)
# Price fluctuates between 50–53.
# Market appears to be consolidating.
# EDA Insights You Can Mention
#
# Trend Analysis
#
# Long-term trend is positive.
# Stock price increased from approximately 47 to 53.
#
# Volatility Analysis
#
# Significant volatility around August 2015 and February 2016.
#
# Support Level
#
# Around 41–43, where the stock bounced back.
#
# Resistance Level
#
# Around 56–57, where the stock struggled to move higher.

# %% [markdown]
# The Microsoft stock price exhibits an overall upward trend with periods of short-term volatility. A major decline occurred in August 2015, followed by a strong recovery and sustained growth until January 2016. The stock reached a peak near 56.5 before undergoing a correction and stabilizing around 52–53. These patterns suggest the presence of a long-term bullish trend with temporary market fluctuations.

# %%
ts1 = ts[23:233]
ts1['High'].plot(figsize = (15, 6))
# Out:
# <Axes: xlabel='Date'>

# %% [markdown]
# The daily high prices of Microsoft stock exhibited a clear upward trend over the observed period. After reaching a low near 43 in September 2015, the stock experienced significant growth and attained a peak close to 57 in January 2016. Although a short-term correction followed, the stock remained above its earlier lows, indicating overall positive market performance.

# %%
ts1 = ts[23:233]
ts1['Low'].plot(figsize = (15, 6))
# Out:
# <Axes: xlabel='Date'>

# %%
ts1 = ts[23:233]
ts1['Volume'].plot(figsize = (15, 6))
# Out:
# <Axes: xlabel='Date'>

# %%
sns.histplot(ts['Close'], kde = True)
plt.show()
ts['Close'].skew()
# Out:
# np.float64(0.8273771005260597)

# %%
sns.boxplot(x=ts['Close'])
# Out:
# <Axes: xlabel='Close'>

# %%
sns.heatmap(ts.corr(numeric_only=True))
# Out:
# <Axes: >

# %%
from statsmodels.tsa.seasonal import seasonal_decompose
import matplotlib.pyplot as plt

def decomposition_check(feature, models):

    result = seasonal_decompose(
        ts[feature],
        model= models,
        period=30
    )

    trend = result.trend
    seasonal = result.seasonal
    residual = result.resid

    plt.figure(figsize=(12,8))

    plt.subplot(411)
    plt.plot(ts[feature], label='Original')
    plt.legend(loc='best')

    plt.subplot(412)
    plt.plot(trend, label='Trend')
    plt.legend(loc='best')

    plt.subplot(413)
    plt.plot(seasonal, label='Seasonal')
    plt.legend(loc='best')

    plt.subplot(414)
    plt.plot(residual, label='Residual')
    plt.legend(loc='best')

    plt.tight_layout()
    plt.show()

# %%
matrix = [
    'Open',
    'Close',
    'High',
    'Low',
    'Volume'
]

for i in matrix:
    decomposition_check(i, 'additive')

# %%
# Stationarity Check
from statsmodels.tsa.stattools import adfuller

result = adfuller(ts['Close'])

print('ADF Statistic: ', result[0])
print('p-value: ', result[1])

for key, value in result[4].items():
    print(f"Critical Value ({key}): {value}")
# Out:
# ADF Statistic:  1.7371362899270957
# p-value:  0.9982158366942122
# Critical Value (1%): -3.4347582315402434
# Critical Value (5%): -2.863486949792871
# Critical Value (10%): -2.567806534528638

# %%
result
# Out:
# (np.float64(1.7371362899270957),
#  np.float64(0.9982158366942122),
#  24,
#  1486,
#  {'1%': np.float64(-3.4347582315402434),
#   '5%': np.float64(-2.863486949792871),
#   '10%': np.float64(-2.567806534528638)},
#  np.float64(6604.225695235948))

# %%
rolling_mean = ts['Close'].rolling(window = 30).mean()
rolling_std = ts['Close'].rolling(window = 30).std()

plt.figure(figsize = (12, 6))
plt.plot(ts['Close'], label = 'Original')
plt.plot(rolling_mean, label = 'rolling_mean')
plt.plot(rolling_std, label = 'rolling_std')
plt.legend()
plt.show()

# %%
ts['Close_diff'] = ts['Close'].diff()

# %%
ts = ts.dropna()

# %%
from statsmodels.tsa.stattools import adfuller

result = adfuller(ts['Close_diff'])
print('p-value: ', result[1])
# Out:
# p-value:  1.5195939917531174e-17

# %%
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf

plot_acf(ts['Close_diff'], lags = 40)
plt.show()

plot_pacf(ts['Close_diff'], lags=40)
plt.show()
